# %%
# !pip install git+https://github.com/Control-RL/Function-Approximation --upgrade

# %%
from torch.distributions import Categorical
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import torch
import torch.optim as optim

# %% [markdown]
# # Model Definition

# %%
gamma = 0.99

class Pi(nn.Module):
    def __init__(self, in_dim, out_dim):
        super(Pi, self).__init__()
        layers = [
            nn.Linear(in_dim, 64),
            nn.ReLU(),
            nn.Linear(64, out_dim),
        ]
        self.model = nn.Sequential(*layers)
        self.onpolicy_reset()
        self.train()  # set training mode

    def onpolicy_reset(self):
        self.log_probs = []
        self.rewards = []

    def forward(self, x):
        pdparam = self.model(x)
        return pdparam

    def act(self, state):
        x = torch.from_numpy(state.astype(np.float32))  # to tensor
        pdparam = self.forward(x)  # forward pass
        pd = torch.distributions.Categorical(logits=pdparam)  # probability distribution
        action = pd.sample()  # pi(a|s) in action via pd
        log_prob = pd.log_prob(action)  # log prob of pi(a|s)
        self.log_probs.append(log_prob)  # store for training
        return action.item()

# %% [markdown]
# # Inner gradient loop of basic policy-gradient algorithm (Reinforce)

# %%
def train(pi, optimizer):
    # Inner gradient-ascent loop of REINFORCE algorithm
    T = len(pi.rewards)
    rets = np.empty(T, dtype=np.float32)  # the returns
    future_ret = 0.0
    # compute the returns efficiently
    for t in reversed(range(T)):
        future_ret = pi.rewards[t] + gamma * future_ret
        rets[t] = future_ret

    # Compute returns
    rets = torch.tensor(rets)
    log_probs = torch.stack(pi.log_probs)
    
    # Compute loss (REINFORCE gradient term)
    loss = -log_probs * rets  # Negative for maximizing
    loss = torch.sum(loss)

    # Perform gradient ascent
    optimizer.zero_grad()
    loss.backward()  # Backpropagate, compute gradients
    optimizer.step()  # Gradient-ascent, update the weights

    return loss

# %% [markdown]
# # Training loop

# %%
env = gym.make('CartPole-v1')

in_dim = env.observation_space.shape[0]  # 4
out_dim = env.action_space.n  # 2

pi = Pi(in_dim, out_dim)  # Policy π_θ for REINFORCE
optimizer = optim.Adam(pi.parameters(), lr=0.01)

for epi in range(300):
    state = env.reset()[0]
    for t in range(200):  # CartPole max timestep is 200
        action = pi.act(state)
        state, reward, done, _, _ = env.step(action)
        pi.rewards.append(reward)
        # env.render()
        if done:
            break

    # Train the policy per episode
    loss = train(pi, optimizer)
    total_reward = sum(pi.rewards)
    solved = total_reward > 195.0

    # On-policy: clear memory after training
    pi.onpolicy_reset()
    print(f'Episode {epi}, loss: {loss}, '
            f'total_reward: {total_reward}, solved: {solved}')
# Out:
# Episode 0, loss: 636.5335693359375, total_reward: 46.0, solved: False
# Episode 1, loss: 285.105224609375, total_reward: 30.0, solved: False
# Episode 2, loss: 109.40056610107422, total_reward: 17.0, solved: False
# Episode 3, loss: 144.4670867919922, total_reward: 21.0, solved: False
# Episode 4, loss: 96.35108947753906, total_reward: 17.0, solved: False
# Episode 5, loss: 293.4607849121094, total_reward: 31.0, solved: False
# Episode 6, loss: 90.36298370361328, total_reward: 16.0, solved: False
# Episode 7, loss: 139.30355834960938, total_reward: 20.0, solved: False
# Episode 8, loss: 275.1560974121094, total_reward: 30.0, solved: False
# Episode 9, loss: 288.7371520996094, total_reward: 31.0, solved: False
# Episode 10, loss: 594.1530151367188, total_reward: 45.0, solved: False
# Episode 11, loss: 44.8603630065918, total_reward: 11.0, solved: False
# Episode 12, loss: 386.4444580078125, total_reward: 36.0, solved: False
# Episode 13, loss: 98.17557525634766, total_reward: 17.0, solved: False
# Episode 14, loss: 72.30890655517578, total_reward: 15.0, solved: False
# Episode 15, loss: 217.79649353027344, total_reward: 27.0, solved: False
# Episode 16, loss: 58.45112609863281, total_reward: 13.0, solved: False
# Episode 17, loss: 39.189659118652344, total_reward: 11.0, solved: False
# Episode 18, loss: 47.40687942504883, total_reward: 12.0, solved: False
# Episode 19, loss: 62.96614456176758, total_reward: 14.0, solved: False
# Episode 20, loss: 179.14810180664062, total_reward: 24.0, solved: False
# Episode 21, loss: 324.9692077636719, total_reward: 33.0, solved: False
# Episode 22, loss: 203.0663299560547, total_reward: 26.0, solved: False
# Episode 23, loss: 169.51376342773438, total_reward: 24.0, solved: False
# Episode 24, loss: 107.70062255859375, total_reward: 19.0, solved: False
# Episode 25, loss: 124.65943145751953, total_reward: 20.0, solved: False
# Episode 26, loss: 198.10679626464844, total_reward: 25.0, solved: False
# Episode 27, loss: 120.11075592041016, total_reward: 18.0, solved: False
# Episode 28, loss: 386.36883544921875, total_reward: 37.0, solved: False
# Episode 29, loss: 171.3394775390625, total_reward: 24.0, solved: False
# Episode 30, loss: 755.6177978515625, total_reward: 52.0, solved: False
# Episode 31, loss: 193.67974853515625, total_reward: 26.0, solved: False
# Episode 32, loss: 356.91595458984375, total_reward: 37.0, solved: False
# Episode 33, loss: 120.72628784179688, total_reward: 20.0, solved: False
# Episode 34, loss: 3021.04052734375, total_reward: 121.0, solved: False
# Episode 35, loss: 540.68896484375, total_reward: 46.0, solved: False
# Episode 36, loss: 4027.735595703125, total_reward: 141.0, solved: False
# Episode 37, loss: 416.2873229980469, total_reward: 41.0, solved: False
# Episode 38, loss: 1232.87060546875, total_reward: 72.0, solved: False
# Episode 39, loss: 928.010986328125, total_reward: 59.0, solved: False
# Episode 40, loss: 467.16119384765625, total_reward: 41.0, solved: False
# Episode 41, loss: 186.42132568359375, total_reward: 26.0, solved: False
# Episode 42, loss: 373.63201904296875, total_reward: 37.0, solved: False
# Episode 43, loss: 392.66265869140625, total_reward: 38.0, solved: False
# Episode 44, loss: 1297.1793212890625, total_reward: 72.0, solved: False
# Episode 45, loss: 178.9763946533203, total_reward: 25.0, solved: False
# Episode 46, loss: 832.9706420898438, total_reward: 57.0, solved: False
# Episode 47, loss: 457.89227294921875, total_reward: 43.0, solved: False
# Episode 48, loss: 293.3064270019531, total_reward: 33.0, solved: False
# Episode 49, loss: 500.2102355957031, total_reward: 44.0, solved: False
# Episode 50, loss: 113.6775131225586, total_reward: 20.0, solved: False
# Episode 51, loss: 661.4440307617188, total_reward: 50.0, solved: False
# Episode 52, loss: 153.25814819335938, total_reward: 24.0, solved: False
# Episode 53, loss: 506.0429992675781, total_reward: 43.0, solved: False
# Episode 54, loss: 1108.89794921875, total_reward: 67.0, solved: False
# Episode 55, loss: 309.0435791015625, total_reward: 32.0, solved: False
# Episode 56, loss: 361.041748046875, total_reward: 39.0, solved: False
# Episode 57, loss: 400.561767578125, total_reward: 37.0, solved: False
# Episode 58, loss: 5536.05859375, total_reward: 181.0, solved: False
# Episode 59, loss: 1706.8743896484375, total_reward: 88.0, solved: False
# Episode 60, loss: 1288.67333984375, total_reward: 71.0, solved: False
# Episode 61, loss: 280.9732360839844, total_reward: 33.0, solved: False
# Episode 62, loss: 1295.6282958984375, total_reward: 80.0, solved: False
# Episode 63, loss: 933.6753540039062, total_reward: 63.0, solved: False
# Episode 64, loss: 2070.558349609375, total_reward: 99.0, solved: False
# Episode 65, loss: 1068.5302734375, total_reward: 73.0, solved: False
# Episode 66, loss: 481.2937316894531, total_reward: 45.0, solved: False
# Episode 67, loss: 347.126708984375, total_reward: 38.0, solved: False
# Episode 68, loss: 564.1947021484375, total_reward: 51.0, solved: False
# Episode 69, loss: 2146.783935546875, total_reward: 103.0, solved: False
# Episode 70, loss: 823.9164428710938, total_reward: 60.0, solved: False
# Episode 71, loss: 858.145751953125, total_reward: 62.0, solved: False
# Episode 72, loss: 1314.0218505859375, total_reward: 80.0, solved: False
# Episode 73, loss: 1338.326416015625, total_reward: 80.0, solved: False
# Episode 74, loss: 713.0413818359375, total_reward: 55.0, solved: False
# Episode 75, loss: 4631.0888671875, total_reward: 174.0, solved: False
# Episode 76, loss: 285.937255859375, total_reward: 35.0, solved: False
# Episode 77, loss: 519.00341796875, total_reward: 50.0, solved: False
# Episode 78, loss: 1471.491455078125, total_reward: 81.0, solved: False
# Episode 79, loss: 1702.9632568359375, total_reward: 93.0, solved: False
# Episode 80, loss: 752.9437866210938, total_reward: 56.0, solved: False
# Episode 81, loss: 916.634033203125, total_reward: 67.0, solved: False
# Episode 82, loss: 3171.505859375, total_reward: 135.0, solved: False
# Episode 83, loss: 1230.9228515625, total_reward: 76.0, solved: False
# Episode 84, loss: 1495.73876953125, total_reward: 86.0, solved: False
# Episode 85, loss: 615.1212768554688, total_reward: 54.0, solved: False
# Episode 86, loss: 702.4181518554688, total_reward: 60.0, solved: False
# Episode 87, loss: 616.8822631835938, total_reward: 51.0, solved: False
# Episode 88, loss: 1590.434326171875, total_reward: 94.0, solved: False
# Episode 89, loss: 942.0813598632812, total_reward: 69.0, solved: False
# Episode 90, loss: 660.959228515625, total_reward: 55.0, solved: False
# Episode 91, loss: 1045.105224609375, total_reward: 75.0, solved: False
# Episode 92, loss: 952.3026123046875, total_reward: 72.0, solved: False
# Episode 93, loss: 876.025146484375, total_reward: 64.0, solved: False
# Episode 94, loss: 535.3353271484375, total_reward: 52.0, solved: False
# Episode 95, loss: 2094.212646484375, total_reward: 100.0, solved: False
# Episode 96, loss: 1606.3438720703125, total_reward: 94.0, solved: False
# Episode 97, loss: 651.1203002929688, total_reward: 57.0, solved: False
# Episode 98, loss: 996.88916015625, total_reward: 72.0, solved: False
# Episode 99, loss: 1755.83935546875, total_reward: 101.0, solved: False
# Episode 100, loss: 484.7822570800781, total_reward: 49.0, solved: False
# Episode 101, loss: 711.3113403320312, total_reward: 58.0, solved: False
# Episode 102, loss: 1360.678466796875, total_reward: 92.0, solved: False
# Episode 103, loss: 977.033203125, total_reward: 70.0, solved: False
# Episode 104, loss: 1574.0767822265625, total_reward: 94.0, solved: False
# Episode 105, loss: 4034.59130859375, total_reward: 166.0, solved: False
# Episode 106, loss: 733.1815185546875, total_reward: 61.0, solved: False
# Episode 107, loss: 1164.303466796875, total_reward: 75.0, solved: False
# Episode 108, loss: 2791.720703125, total_reward: 120.0, solved: False
# Episode 109, loss: 1119.171630859375, total_reward: 76.0, solved: False
# Episode 110, loss: 936.482666015625, total_reward: 66.0, solved: False
# Episode 111, loss: 781.2579345703125, total_reward: 61.0, solved: False
# Episode 112, loss: 1195.51611328125, total_reward: 78.0, solved: False
# Episode 113, loss: 2573.79443359375, total_reward: 119.0, solved: False
# Episode 114, loss: 2681.588134765625, total_reward: 126.0, solved: False
# Episode 115, loss: 925.8529663085938, total_reward: 69.0, solved: False
# Episode 116, loss: 1114.7659912109375, total_reward: 83.0, solved: False
# Episode 117, loss: 1056.01806640625, total_reward: 76.0, solved: False
# Episode 118, loss: 862.8040771484375, total_reward: 69.0, solved: False
# Episode 119, loss: 1008.9482421875, total_reward: 74.0, solved: False
# Episode 120, loss: 515.1658935546875, total_reward: 46.0, solved: False
# Episode 121, loss: 1267.6558837890625, total_reward: 78.0, solved: False
# Episode 122, loss: 406.38763427734375, total_reward: 46.0, solved: False
# Episode 123, loss: 519.3152465820312, total_reward: 42.0, solved: False
# Episode 124, loss: 912.9378051757812, total_reward: 69.0, solved: False
# Episode 125, loss: 574.594482421875, total_reward: 50.0, solved: False
# Episode 126, loss: 431.97186279296875, total_reward: 48.0, solved: False
# Episode 127, loss: 1005.3199462890625, total_reward: 65.0, solved: False
# Episode 128, loss: 1002.9711303710938, total_reward: 71.0, solved: False
# Episode 129, loss: 317.4828796386719, total_reward: 41.0, solved: False
# Episode 130, loss: 923.7772216796875, total_reward: 71.0, solved: False
# Episode 131, loss: 726.3707275390625, total_reward: 55.0, solved: False
# Episode 132, loss: 1270.6204833984375, total_reward: 78.0, solved: False
# Episode 133, loss: 504.31768798828125, total_reward: 48.0, solved: False
# Episode 134, loss: 323.6828918457031, total_reward: 37.0, solved: False
# Episode 135, loss: 674.280517578125, total_reward: 56.0, solved: False
# Episode 136, loss: 220.22027587890625, total_reward: 32.0, solved: False
# Episode 137, loss: 1057.914306640625, total_reward: 73.0, solved: False
# Episode 138, loss: 976.436279296875, total_reward: 68.0, solved: False
# Episode 139, loss: 318.2842712402344, total_reward: 32.0, solved: False
# Episode 140, loss: 835.1185913085938, total_reward: 62.0, solved: False
# Episode 141, loss: 1249.9886474609375, total_reward: 71.0, solved: False
# Episode 142, loss: 366.4350891113281, total_reward: 37.0, solved: False
# Episode 143, loss: 732.5693359375, total_reward: 56.0, solved: False
# Episode 144, loss: 1537.500732421875, total_reward: 87.0, solved: False
# Episode 145, loss: 930.5460815429688, total_reward: 66.0, solved: False
# Episode 146, loss: 2057.616455078125, total_reward: 104.0, solved: False
# Episode 147, loss: 681.7506103515625, total_reward: 56.0, solved: False
# Episode 148, loss: 956.508056640625, total_reward: 67.0, solved: False
# Episode 149, loss: 959.7103881835938, total_reward: 69.0, solved: False
# Episode 150, loss: 973.2872314453125, total_reward: 66.0, solved: False
# Episode 151, loss: 1141.3138427734375, total_reward: 71.0, solved: False
# Episode 152, loss: 809.8627319335938, total_reward: 64.0, solved: False
# Episode 153, loss: 1728.231689453125, total_reward: 90.0, solved: False
# Episode 154, loss: 1367.588623046875, total_reward: 83.0, solved: False
# Episode 155, loss: 1403.843994140625, total_reward: 82.0, solved: False
# Episode 156, loss: 1441.7037353515625, total_reward: 86.0, solved: False
# Episode 157, loss: 2456.8984375, total_reward: 111.0, solved: False
# Episode 158, loss: 1679.92333984375, total_reward: 92.0, solved: False
# Episode 159, loss: 1054.0555419921875, total_reward: 68.0, solved: False
# Episode 160, loss: 2494.588134765625, total_reward: 111.0, solved: False
# Episode 161, loss: 1995.58154296875, total_reward: 101.0, solved: False
# Episode 162, loss: 3341.0205078125, total_reward: 135.0, solved: False
# Episode 163, loss: 3807.9970703125, total_reward: 150.0, solved: False
# Episode 164, loss: 3934.32861328125, total_reward: 145.0, solved: False
# Episode 165, loss: 3523.186279296875, total_reward: 137.0, solved: False
# Episode 166, loss: 3273.075439453125, total_reward: 138.0, solved: False
# Episode 167, loss: 3844.214111328125, total_reward: 151.0, solved: False
# Episode 168, loss: 5321.97216796875, total_reward: 174.0, solved: False
# Episode 169, loss: 5093.4951171875, total_reward: 178.0, solved: False
# Episode 170, loss: 4839.03955078125, total_reward: 171.0, solved: False
# Episode 171, loss: 5043.46142578125, total_reward: 176.0, solved: False
# Episode 172, loss: 5975.9296875, total_reward: 200.0, solved: True
# Episode 173, loss: 6021.62060546875, total_reward: 200.0, solved: True
# Episode 174, loss: 6409.4482421875, total_reward: 194.0, solved: False
# Episode 175, loss: 6403.84619140625, total_reward: 200.0, solved: True
# Episode 176, loss: 4943.16015625, total_reward: 166.0, solved: False
# Episode 177, loss: 4437.62109375, total_reward: 162.0, solved: False
# Episode 178, loss: 2635.037109375, total_reward: 116.0, solved: False
# Episode 179, loss: 2626.9013671875, total_reward: 112.0, solved: False
# Episode 180, loss: 314.7988586425781, total_reward: 35.0, solved: False
# Episode 181, loss: 1223.8067626953125, total_reward: 74.0, solved: False
# Episode 182, loss: 2030.849853515625, total_reward: 97.0, solved: False
# Episode 183, loss: 302.1756591796875, total_reward: 36.0, solved: False
# Episode 184, loss: 1434.7330322265625, total_reward: 83.0, solved: False
# Episode 185, loss: 665.8843383789062, total_reward: 52.0, solved: False
# Episode 186, loss: 183.15814208984375, total_reward: 27.0, solved: False
# Episode 187, loss: 129.14627075195312, total_reward: 23.0, solved: False
# Episode 188, loss: 1930.0870361328125, total_reward: 98.0, solved: False
# Episode 189, loss: 511.64288330078125, total_reward: 46.0, solved: False
# Episode 190, loss: 2548.890869140625, total_reward: 113.0, solved: False
# Episode 191, loss: 272.89581298828125, total_reward: 33.0, solved: False
# Episode 192, loss: 134.83238220214844, total_reward: 24.0, solved: False
# Episode 193, loss: 172.9815216064453, total_reward: 25.0, solved: False
# Episode 194, loss: 3989.66064453125, total_reward: 148.0, solved: False
# Episode 195, loss: 139.84146118164062, total_reward: 23.0, solved: False
# Episode 196, loss: 6238.2275390625, total_reward: 191.0, solved: False
# Episode 197, loss: 6230.4814453125, total_reward: 200.0, solved: True
# Episode 198, loss: 6403.33544921875, total_reward: 200.0, solved: True
# Episode 199, loss: 6348.77978515625, total_reward: 200.0, solved: True
# Episode 200, loss: 6260.81494140625, total_reward: 195.0, solved: False
# Episode 201, loss: 6586.099609375, total_reward: 200.0, solved: True
# Episode 202, loss: 6172.2138671875, total_reward: 200.0, solved: True
# Episode 203, loss: 5959.970703125, total_reward: 200.0, solved: True
# Episode 204, loss: 6187.576171875, total_reward: 200.0, solved: True
# Episode 205, loss: 6093.9306640625, total_reward: 200.0, solved: True
# Episode 206, loss: 6181.66455078125, total_reward: 200.0, solved: True
# Episode 207, loss: 5937.11962890625, total_reward: 200.0, solved: True
# Episode 208, loss: 6223.95947265625, total_reward: 200.0, solved: True
# Episode 209, loss: 6088.677734375, total_reward: 200.0, solved: True
# Episode 210, loss: 6345.103515625, total_reward: 200.0, solved: True
# Episode 211, loss: 6301.646484375, total_reward: 200.0, solved: True
# Episode 212, loss: 5935.802734375, total_reward: 200.0, solved: True
# Episode 213, loss: 6952.57958984375, total_reward: 200.0, solved: True
# Episode 214, loss: 6210.90185546875, total_reward: 200.0, solved: True
# Episode 215, loss: 6224.06982421875, total_reward: 200.0, solved: True
# Episode 216, loss: 5994.42431640625, total_reward: 200.0, solved: True
# Episode 217, loss: 6461.5390625, total_reward: 200.0, solved: True
# Episode 218, loss: 6324.60400390625, total_reward: 200.0, solved: True
# Episode 219, loss: 6006.08544921875, total_reward: 200.0, solved: True
# Episode 220, loss: 6020.39892578125, total_reward: 200.0, solved: True
# Episode 221, loss: 6073.38623046875, total_reward: 200.0, solved: True
# Episode 222, loss: 6287.8671875, total_reward: 200.0, solved: True
# Episode 223, loss: 6020.25537109375, total_reward: 200.0, solved: True
# Episode 224, loss: 6160.08544921875, total_reward: 200.0, solved: True
# Episode 225, loss: 6185.52978515625, total_reward: 200.0, solved: True
# Episode 226, loss: 5525.7666015625, total_reward: 200.0, solved: True
# Episode 227, loss: 5469.33740234375, total_reward: 200.0, solved: True
# Episode 228, loss: 6054.6279296875, total_reward: 200.0, solved: True
# Episode 229, loss: 5686.111328125, total_reward: 200.0, solved: True
# Episode 230, loss: 4969.4990234375, total_reward: 200.0, solved: True
# Episode 231, loss: 5841.26318359375, total_reward: 200.0, solved: True
# Episode 232, loss: 5167.99755859375, total_reward: 193.0, solved: False
# Episode 233, loss: 5120.283203125, total_reward: 200.0, solved: True
# Episode 234, loss: 4983.1943359375, total_reward: 189.0, solved: False
# Episode 235, loss: 5142.40234375, total_reward: 200.0, solved: True
# Episode 236, loss: 5016.2685546875, total_reward: 200.0, solved: True
# Episode 237, loss: 5280.44091796875, total_reward: 200.0, solved: True
# Episode 238, loss: 5206.095703125, total_reward: 200.0, solved: True
# Episode 239, loss: 5097.3369140625, total_reward: 200.0, solved: True
# Episode 240, loss: 4646.4521484375, total_reward: 200.0, solved: True
# Episode 241, loss: 5083.90625, total_reward: 200.0, solved: True
# Episode 242, loss: 4574.0947265625, total_reward: 200.0, solved: True
# Episode 243, loss: 5358.07861328125, total_reward: 200.0, solved: True
# Episode 244, loss: 4584.87109375, total_reward: 200.0, solved: True
# Episode 245, loss: 4796.40283203125, total_reward: 200.0, solved: True
# Episode 246, loss: 4963.11572265625, total_reward: 200.0, solved: True
# Episode 247, loss: 5236.28125, total_reward: 200.0, solved: True
# Episode 248, loss: 4912.86328125, total_reward: 200.0, solved: True
# Episode 249, loss: 4714.6572265625, total_reward: 200.0, solved: True
# Episode 250, loss: 4984.4677734375, total_reward: 200.0, solved: True
# Episode 251, loss: 5307.755859375, total_reward: 200.0, solved: True
# Episode 252, loss: 5254.67431640625, total_reward: 200.0, solved: True
# Episode 253, loss: 5012.27197265625, total_reward: 200.0, solved: True
# Episode 254, loss: 4624.00048828125, total_reward: 200.0, solved: True
# Episode 255, loss: 5537.45849609375, total_reward: 200.0, solved: True
# Episode 256, loss: 4780.92626953125, total_reward: 200.0, solved: True
# Episode 257, loss: 5334.79150390625, total_reward: 200.0, solved: True
# Episode 258, loss: 4769.8662109375, total_reward: 200.0, solved: True
# Episode 259, loss: 5285.27099609375, total_reward: 200.0, solved: True
# Episode 260, loss: 5485.005859375, total_reward: 200.0, solved: True
# Episode 261, loss: 4867.7314453125, total_reward: 200.0, solved: True
# Episode 262, loss: 4713.90966796875, total_reward: 200.0, solved: True
# Episode 263, loss: 5566.447265625, total_reward: 200.0, solved: True
# Episode 264, loss: 5340.564453125, total_reward: 200.0, solved: True
# Episode 265, loss: 4705.06396484375, total_reward: 200.0, solved: True
# Episode 266, loss: 4989.568359375, total_reward: 200.0, solved: True
# Episode 267, loss: 5248.18994140625, total_reward: 200.0, solved: True
# Episode 268, loss: 5571.8291015625, total_reward: 200.0, solved: True
# Episode 269, loss: 5278.67333984375, total_reward: 200.0, solved: True
# Episode 270, loss: 5104.17138671875, total_reward: 200.0, solved: True
# Episode 271, loss: 5452.79931640625, total_reward: 200.0, solved: True
# Episode 272, loss: 4537.056640625, total_reward: 200.0, solved: True
# Episode 273, loss: 5400.4072265625, total_reward: 200.0, solved: True
# Episode 274, loss: 5175.73046875, total_reward: 200.0, solved: True
# Episode 275, loss: 5174.08251953125, total_reward: 200.0, solved: True
# Episode 276, loss: 5378.55078125, total_reward: 200.0, solved: True
# Episode 277, loss: 5353.95751953125, total_reward: 200.0, solved: True
# Episode 278, loss: 5393.45947265625, total_reward: 200.0, solved: True
# Episode 279, loss: 5124.9716796875, total_reward: 200.0, solved: True
# Episode 280, loss: 5223.91357421875, total_reward: 200.0, solved: True
# Episode 281, loss: 6578.19921875, total_reward: 200.0, solved: True
# Episode 282, loss: 5214.7412109375, total_reward: 200.0, solved: True
# Episode 283, loss: 5425.9482421875, total_reward: 200.0, solved: True
# Episode 284, loss: 5364.650390625, total_reward: 200.0, solved: True
# Episode 285, loss: 5592.4208984375, total_reward: 200.0, solved: True
# Episode 286, loss: 5560.822265625, total_reward: 200.0, solved: True
# Episode 287, loss: 5748.77685546875, total_reward: 200.0, solved: True
# Episode 288, loss: 6061.2890625, total_reward: 200.0, solved: True
# Episode 289, loss: 6038.361328125, total_reward: 200.0, solved: True
# Episode 290, loss: 5817.50537109375, total_reward: 200.0, solved: True
# Episode 291, loss: 5811.74462890625, total_reward: 200.0, solved: True
# Episode 292, loss: 5900.93798828125, total_reward: 200.0, solved: True
# Episode 293, loss: 5914.16796875, total_reward: 200.0, solved: True
# Episode 294, loss: 5639.57958984375, total_reward: 200.0, solved: True
# Episode 295, loss: 5601.8720703125, total_reward: 200.0, solved: True
# Episode 296, loss: 5909.56298828125, total_reward: 200.0, solved: True
# Episode 297, loss: 6034.80712890625, total_reward: 200.0, solved: True
# Episode 298, loss: 5775.49267578125, total_reward: 200.0, solved: True
# Episode 299, loss: 6154.763671875, total_reward: 200.0, solved: True

# %% [markdown]
# # Record the agent

# %%
from gymnasium.wrappers import RecordVideo
from typing import Optional
import os

# %%
def evaluate(
    pi: Pi,
    env: gym.Env,
    n_eval_episodes: int = 10,
    video_name: Optional[str] = None,
) -> None:
    episode_returns, episode_reward = [], 0.0
    total_episodes = 0
    done = False

    # Setup video recorder
    video_recorder = None
    if video_name is not None and env.render_mode == "rgb_array":
        os.makedirs("../logs/videos/", exist_ok=True)

        # New gym recorder always wants to cut video into episodes,
        # set video length big enough but not to inf (will cut into episodes)
        env = RecordVideo(env, "../logs/videos", step_trigger=lambda _: False, video_length=100_000)
        env.start_recording(video_name)

    obs, _ = env.reset()
    n_actions = int(env.action_space.n)

    while total_episodes < n_eval_episodes:

        ### YOUR CODE HERE
        action = pi.act(obs)


        # Send the action to the env
        obs, reward, terminated, truncated, _ = env.step(action)

        ### END OF YOUR CODE

        episode_reward += float(reward)

        done = terminated or truncated
        if done:
            episode_returns.append(episode_reward)
            episode_reward = 0.0
            total_episodes += 1
            obs, _ = env.reset()

    if isinstance(env, RecordVideo):
        print(f"Saving video to ../logs/videos/{video_name}")
        env.close()

    print(f"Total reward = {np.mean(episode_returns):.2f} +/- {np.std(episode_returns):.2f}")

# %%
env_id = "CartPole-v1"

eval_env = gym.make(env_id, render_mode="rgb_array")
video_name = f"PG_{env_id}.mp4"
n_eval_episodes = 3

# %%
evaluate(pi, eval_env, n_eval_episodes, video_name=video_name)
# Out:
# /home/guillaumep/miniconda3/envs/ct-rl/lib/python3.10/site-packages/gymnasium/wrappers/rendering.py:283: UserWarning: WARN: Overwriting existing videos at /home/guillaumep/ct-rl_tutorials/rlss23-dqn-tutorial-main/notebooks_summer_school/logs/videos folder (try specifying a different `video_folder` for the `RecordVideo` wrapper if this is not desired)
#   logger.warn(
# Saving video to ../logs/videos/PG_CartPole-v1.mp4
# Total reward = 500.00 +/- 0.00

# %%
from dqn_tutorial.notebook_utils import show_videos

print(f"PG agent on {env_id} after 300 iterations:")
show_videos("../logs/videos/", prefix=video_name)
# Out:
# PG agent on CartPole-v1 after 300 iterations:
# <video alt="../logs/videos/PG_CartPole-v1.mp4.mp4" autoplay
#                     loop controls style="height: 400px;">
#                     <source src="data:video/mp4;base64,..." type="video/mp4" />
#                 </video>
